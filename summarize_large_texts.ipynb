# %% [markdown]
# # Summarizing a  text (That does not fit in LLM)

# %% [markdown]
# ## First Method  "Recursive Summaries" Method
# The "Recursive Summaries" method is an effective approach to condense a  text that exceeds the context window (max_tokens) of a Language Learning Model (LLM), such as gpt-3.5-turbo-0125, which has a limit of 16,385 tokens. This method involves dividing the text into manageable chunks, summarizing each chunk, and then summarizing the summaries to create a concise and coherent summary of the original text.
#
# ### Step 1: Splitting the Text:
# The first step in the "Recursive Summaries" method is to split the  text into smaller chunks. Each chunk should have a size to fit within the token limit of your LLM. For instance, in our case (gpt-3.5-turbo-0125 the max number of tokens is 16,385 tokens, so the input text and the summary should not exceed this token limit). It would be a good idea to take 16,385 – N tokens as input, and keep as maximum N tokens for output. N can be specified according to the size of text, if the text is too , should take into consideration that N * nb of chunks should not pass the LLM context size. A good approach is to calculate N in this step to ensure that the LLM can process each chunk effectively without exceeding its token limit. For example if the initial text is 1M tokens, and each chunck is 15000 tokens, the number of chunks will be 67. We must be sure that 67 * N is less than the context size.
#
# ### Step 2: Summarizing Each Chunk:
# Once the text has been divided into manageable chunks, the next step is to create a summary for each chunk. This can be done by feeding each chunk into the LLM and asking it to generate a summary. The LLM will process each chunk and produce a summary that captures the main points and ideas of the chunk. This step ensures that the most important information from each chunk is retained. (You can set a limit for the LLM to not exceed a certain number of words for each summary)
# Step 3: Grouping the Summaries:
# After summarizing each chunk, the next step is to group all the summaries together. This creates a new text that is composed entirely of the summaries of the original chunks. This new text is typically much shorter than the original text, but it still contains all the main points and ideas.
#
# ### Step 4: Summarizing the Summaries:
# The final step in the "Recursive Summaries" method is to create a summary of the summaries. This can be done by feeding the new text (i.e., the group of summaries) into the LLM and asking it to generate a summary. The LLM will process the new text and produce a summary that captures the main points and ideas of all the summaries. This final summary is a concise and coherent summary of the original  text.
#
# The "Recursive Summaries" method is a powerful tool for summarizing  texts that exceed the token limit of a Language Learning Model. By dividing the text into manageable chunks, summarizing each chunk, grouping the summaries, and summarizing the summaries, this method allows you to create a concise and coherent summary of the original text. This method ensures that the most important information from the original text is retained, even when the text is too  to be processed by the LLM in its entirety. One of the drawbacks of this method is that summary of summaries can loose some information from the original text.

# %%
import os
import time
import requests
import json
import tiktoken
import PyPDF2
from dotenv import load_dotenv

env_path = 'C:\\Users\\user\\Desktop\\My_Files\\Anaconda  Projects\\DevTechPro\\.env'
load_dotenv(dotenv_path=env_path)
OPENAI_API_KEY= os.getenv('OPENAI_API_KEY')

# %% [markdown]
# This Python function call_openai serves as an interface to the OpenAI API for generating text-based responses using a specified model. Here's a breakdown of how it works:
#
# - Input Parameters: The function takes several parameters:
# - system_prompt: A prompt to provide context or guidance to the model.
# - user_prompt: A prompt representing the user's input or query.
# - is_json: A boolean indicating whether the response format should be JSON.
# - model_name: The name of the model to use (defaults to 'gpt-3.5-turbo-0125').
# - temperature: A parameter controlling the randomness of the generated responses.
# - max_tokens: The maximum number of tokens (words or subwords) in the generated response.
# - max_retries: The maximum number of retry attempts in case of failure.
# - backoff_factor: A factor by which the wait time between retries increases.
# - openai_api_key: An API key required for authentication with the OpenAI API.
# - print_results: A boolean indicating whether to print the response JSON.
#
# Retry Mechanism: The function attempts to call the OpenAI API multiple times (max_retries) in case of failure, with an increasing delay between attempts (backoff_factor). This mechanism helps handle transient errors and network issues.
# Building the Request Payload: The function constructs the request payload based on the input parameters, including the model name, prompts, temperature, and maximum tokens. If is_json is True, it includes additional parameters for specifying the response format as JSON.
#
# Sending the Request: Using the requests.post method, the function sends a POST request to the OpenAI API endpoint (https://api.openai.com/v1/chat/completions) with the constructed payload and authentication headers.
# Handling the Response: If the response status code is 200 (indicating success), it optionally prints the response JSON (print_results) and returns the response object. Otherwise, it raises an exception indicating a non-200 status code.
# Error Handling: In case of any exception during the API call, the function handles it by printing an error message (if print_results is True) and waiting for a certain duration before retrying. The wait duration increases exponentially with each attempt to avoid overwhelming the API.

# %%
# # These are many options to split text by characters (Will list them for documentation only)

# #Fixed-size chunking
# from langchain.text_splitter import CharacterTextSplitter
# text_splitter = CharacterTextSplitter(separator = "\n\n",chunk_size = 256,chunk_overlap  = 20)

# # Meaningful chunks with nltk : nltk helps in dividing texts into meanigful chunks
# from langchain.text_splitter import NLTKTextSplitter
# text_splitter = NLTKTextSplitter() 

# # spaCy: spaCy is another powerful Python library for NLP tasks. It offers a sophisticated sentence segmentation feature that can efficiently divide the text into separate sentences, enabling better context preservation in the resulting chunks.
# from langchain.text_splitter import SpacyTextSplitter
# text_splitter = SpacyTextSplitter() 

# # Recursive Chunking
# from langchain.text_splitter import RecursiveCharacterTextSplitter
# text_splitter = RecursiveCharacterTextSplitter(chunk_size = 256,chunk_overlap  = 20)

# # Sfter choosing the best text_splitter, you can pass the the text to text splitter and get the chunks
# # docs = text_splitter.create_documents([text])

# %% [markdown]
# If we split a text by number of characters, it is not obvious how many tokens these chunks will be.
# And at the same time if we want to split a text into bigger possible chunks and keep these chunks under certain LLM tokens limit, we cannot operate by number of characters.
#
# The better option will be to split by tokens with an overlap so that the chunks will not loose the meaning from previous chunks:

# %%
test = """
Once upon a time, in a faraway kingdom nestled between towering mountains and lush forests, there lived a humble blacksmith named William. He resided in a quaint cottage on the outskirts of the village, where the rhythmic clang of his hammer against the anvil echoed through the serene countryside.

William was not just an ordinary blacksmith; he possessed a rare gift bestowed upon him by the gods themselves. His creations were not mere tools or weapons; they were masterpieces, imbued with magic and infused with the essence of the elements.

One chilly autumn morning, as William was busy forging a new sword for the king's royal guard, a stranger arrived at his doorstep. The stranger was tall and cloaked in a dark hooded robe that concealed his features. He spoke in a deep, melodious voice that sent shivers down William's spine.

"I've heard tales of your craftsmanship, blacksmith," the stranger said, his voice carrying an air of mystery. "I seek a weapon of great power, one that can vanquish even the mightiest of foes. Can you help me?"

William hesitated, sensing an aura of darkness surrounding the stranger. But his curiosity got the better of him, and he agreed to forge the weapon the stranger desired.

For days and nights, William toiled tirelessly in his forge, pouring his heart and soul into crafting the most exquisite weapon he had ever made. He forged it from the rarest metals and enchanted it with ancient runes of protection and destruction.

Finally, after weeks of labor, the weapon was complete. It gleamed in the firelight, its blade shimmering with otherworldly energy. William handed it to the stranger, who nodded in silent approval.

But as the stranger took hold of the weapon, a sinister grin spread across his face. "Thank you, blacksmith," he said, his voice dripping with malice. "With this weapon in my hands, I shall unleash chaos upon the land."

Before William could react, the stranger vanished into thin air, leaving behind only a trail of darkness. Horrified by what he had unwittingly unleashed, William knew he had to set things right.

Arming himself with his trusty hammer and the few weapons he had left, William embarked on a perilous journey to stop the stranger and reclaim the weapon he had forged. Along the way, he encountered fierce monsters, treacherous landscapes, and unlikely allies.

But with courage in his heart and determination in his soul, William pressed on, knowing that the fate of the kingdom rested in his hands. And as he finally confronted the stranger in a climactic showdown atop the highest peak of the mountains, he realized that the true power lay not in the weapon he had forged, but in the strength of his spirit and the purity of his intentions.

In the end, it was not blades or spells that decided the outcome of the battle, but the unyielding will of a humble blacksmith who refused to let darkness triumph over light. And as the sun rose once more over the kingdom, casting its golden rays upon the land, William knew that peace had been restored, and that his journey was finally at an end.

But even as he returned to his forge, ready to resume his life of quiet solitude, William could not help but wonder what other adventures awaited him beyond the horizon. For in a world filled with magic and mystery, anything was possible for those brave enough to dream.

And so, the legend of William the blacksmith lived on, whispered in the winds and sung in the songs of bards, a testament to the power of courage, friendship, and the indomitable human spirit.

The end."""

# %%
a = [1,2,3,4]
b = [5,6,7,8]
a.ex(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
# Get the tokenization encoder object from tiktoken library
tokenizer = tiktoken.get_encoding("p50k_base")

def read_text_from_pdf(pdf_path):
    text = ""
    try:
        with open(pdf_path, "rb") as file:
            # Create a PDF file reader object
            pdf_reader = PyPDF2.PdfReader(file)
            
            # Iterate through each page of the PDF
            for page_number in range(len(pdf_reader.pages)):
                # Extract text from the page
                page = pdf_reader.pages[page_number]
                text += page.extract_text()
    except Exception as e:
        print(f"Error: {e}")

    return text

def call_openai(system_prompt, user_prompt, is_json=False, model_name='gpt-3.5-turbo-0125', temperature=0.7, max_tokens=600, max_retries=6, backoff_factor=1.5, openai_api_key=OPENAI_API_KEY, print_results=False):
    for attempt in range(max_retries):
        try:
            #https://platform.openai.com/docs/api-reference/chat/create?lang=python
            messages = [{'role': 'system', 'content': system_prompt},
                        {'role': 'user', 'content': user_prompt}]
            url = 'https://api.openai.com/v1/chat/completions'
            if is_json:
                payload = json.dumps({
                    'model': model_name,
                    'messages': messages,
                    'temperature': temperature,
                    'max_tokens': max_tokens,
                    'response_format':{ "type": "json_object" },
            })
            else:
                payload = json.dumps({
                    'model': model_name,
                    'messages': messages,
                    'temperature': temperature,
                    'max_tokens': max_tokens,
            })
            headers = {'Content-Type': 'application/json',
                       'Authorization': f'Bearer {openai_api_key}'}
            response = requests.post(url, data=payload, headers=headers)
            if response.status_code == 200:
                if print_results:
                    print(response.json())
                return response
            else:
                raise Exception('Non-200 response received')
        except Exception as e:
            if print_results:
                print(response.json())
                print(f'Attempt {attempt+1} failed: {e}')
            time.sleep(backoff_factor ** attempt)
       
def split_text(text, max_tokens, chunk_overlap=100): 
    tokenized_text = tokenizer.encode(text)
    chunks = []
    current_chunk = []
    current_length = 0
    overlap = [] 
    
    for token in tokenized_text: 
        current_chunk.append(token)
        current_length += 1 

        if current_length >= max_tokens:
            chunks.append(tokenizer.decode(current_chunk).rstrip(' .,;'))
            overlap = current_chunk[-chunk_overlap:] 
            current_chunk = []
            current_chunk.extend(overlap)
            current_length = len(overlap)

    if current_chunk:
        chunks.append(tokenizer.decode(current_chunk).rstrip(' .,;'))

    return chunks

def summarize_text(text):
    system_prompt = f"""You are a summary expert, Make a summary of the given text with keeping all the important information."""
    user_prompt = f"""Summarize the following text:
    {text}""" #9 tokens
    response = call_openai(system_prompt, user_prompt)
    return response.json()['choices'][0]['message']['content'].strip()

def summarize_chunks(text):
    system_prompt = "You are a summary expert, You will be given many summaries of chunks of a large text , make a summary of these summaries that contain most of the information from chunks. "
    user_prompt = f"""Summarize the following text: 
    {text}""" #9 tokens
    response = call_openai(system_prompt, user_prompt, max_tokens=250, temperature=0.7)
    return response.json()['choices'][0]['message']['content'].strip()

def recursive_summarize(text, max_tokens=16000, chunk_overlap=100):
    #Should take into consideration also the user prompt length
    user_prompt = f"""Summarize the following text:   """ #7 tokens user prompt without text
    max_tokens = max_tokens - len(tokenizer.encode(user_prompt))
    chunks = split_text(text, max_tokens, chunk_overlap=chunk_overlap)

    summaries = [summarize_text(chunk) for chunk in chunks]
    print("Suammaries of Chunks: \n")
    for i,summary in enumerate(summaries):
        print(f"Summary {i}:\n", summary,'\n')
    grouped_summaries = " ".join(summaries)   

    if len(tokenizer.encode(grouped_summaries)) < max_tokens:
        final_summary = summarize_chunks(grouped_summaries)
    else:
        final_summary = recursive_summarize(grouped_summaries)

    return final_summary

# %%
# pdf_path = "Kolmogorov-Arnold Networks.pdf"
pdf_path = "pride and prejudice.pdf"
text = read_text_from_pdf(pdf_path)
summary = recursive_summarize(text)

print("\nFinal Summary: ", summary)
# Out:
# Suammaries of Chunks:
#
# Summary 0:
#  The text discusses the various novels by Jane Austen, highlighting the distinctions and preferences among her works. It mentions the different characteristics and admirers of each novel, such as "Northanger Abbey," "Persuasion," "Mansfield Park," "Sense and Sensibility," "Emma," and "Pride and Prejudice." The text argues in favor of "Pride and Prejudice" as the most perfect and quintessential work of Austen, emphasizing its construction and plot development. It also discusses the author's talent in character development and dialogue. The text recognizes the novel's superiority in construction and praises its plot, character relationships, and overall storytelling.
#
# Summary 1:
#  The text discusses Jane Austen's unique humor and character portrayal in her works, particularly focusing on "Pride and Prejudice." It highlights the subtle and delicate nature of Austen's humor, comparing it to that of Addison. The text also delves into the misinterpretation of Austen's supposed cynicism and her skill in dissecting and portraying characters. Austen's artistry is praised for its perfection within her chosen field, and her ability to create a complete impression with seemingly trivial details. The text concludes by emphasizing Austen's profound understanding of humanity and art, despite her limited exposure, and commends her realism in storytelling.
#
# Summary 2:
#  The text discusses the novel "Pride and Prejudice" by Jane Austen, praising the meticulous details and character development in the story. It highlights the greatness of the character Mr. Collins, comparing him to Swift and Addison in terms of literary quality. The text also touches on the portrayal of minor characters like Mrs. Bennet, Kitty, Lydia, and Mary, noting the skillful differentiation of their personalities. Additionally, it mentions characters like Mr. Bennet, Lady Catherine de Bourgh, and Charlotte Lucas, appreciating the depth of their portrayals. The text concludes by praising the hero, Mr. Darcy, as one of the most intriguing characters in Austen's work.
#
# Summary 3:
#  The text discusses the characters of Mr. Darcy and Elizabeth Bennet in Jane Austen's novels. It praises Darcy as the best hero with rational pride and genuine love, while Elizabeth is portrayed as clever, strong-minded, and devoid of ill-nature. The text highlights Elizabeth's unique charm, fearlessness, and freedom from societal expectations. It concludes by asserting Elizabeth's unmatched appeal among heroines in literature.
#
# Summary 4:
#  The text describes Mrs. Bennet informing Mr. Bennet about a wealthy young man named Bingley who has taken residence at Netherfield Park, sparking Mrs. Bennet's hopes of him marrying one of their daughters. Mr. Bennet shows indifference but agrees to visit Bingley. The conversation highlights Mrs. Bennet's eagerness to secure advantageous marriages for her daughters.
#
# Summary 5:
#  The text revolves around a conversation between Mr. Bennet and his wife regarding Mr. Bingley's visit. Mr. Bennet expresses his consent for Mr. Bingley to marry any of their daughters, particularly praising Lizzy. Mrs. Bennet disagrees, criticizing her daughters and favoring Jane and Lydia over Lizzy. Mr. Bennet's sarcastic humor and peculiar character are highlighted, causing misunderstandings with his wife. The family anticipates Mr. Bingley's return and plans to introduce him formally. Despite Mrs. Bennet's efforts, Mr. Bennet avoids giving a clear description of Mr. Bingley. The chapter ends with the family speculating about Mr. Bingley's next visit and planning to invite him to dinner.
#
# Summary 6:
#  Mrs. Bennet and her daughters try to gather information about Mr. Bingley but are unsuccessful until they receive positive feedback from Lady Lucas. Mr. Bingley is described as young, handsome, and pleasant, planning a large party. Despite initial excitement, a dinner invitation is postponed due to Mr. Bingley's sudden departure to town. When he finally arrives with a smaller party for the assembly, opinions about him and his friend, Mr. Darcy, differ. Mr. Bingley is sociable and amiable, while Mr. Darcy is seen as proud and disagreeable, particularly by Mrs. Bennet. Mr. Darcy offends Elizabeth Bennet, leading to a strained interaction between them. The evening ends pleasantly for the Bennet family with Jane receiving attention from Mr. Bingley and positive remarks about her sisters.
#
# Summary 7:
#  The Bennet family, including Jane, Elizabeth, Mary, Catherine, and Lydia, return home after attending a ball at Netherfield, where Jane received admiration from Mr. Bingley. Mrs. Bennet is thrilled with the evening and gushes about Mr. Bingley's attention to Jane. Mr. Bennet is less enthusiastic, finding Mr. Bingley's actions excessive. Jane and Elizabeth discuss Mr. Bingley's character, with Jane admiring him and Elizabeth being more reserved in her judgment. The Bingley siblings are described as proud and conceited, coming from a wealthy background. Mr. Bingley inherits a large fortune but is not eager to purchase an estate. His sisters are keen on him acquiring one, but for now, they are content with their situation at Netherfield.
#
# Summary 8:
#  The text describes the relationship dynamics between Mr. Bingley, Mr. Darcy, and the Bennet family in "Pride and Prejudice." Mr. Bingley is easily influenced and amiable, leading to a close friendship with Mr. Darcy, who is more reserved and judgmental. The narrative also introduces Sir William Lucas and his family, who have moved to Lucas Lodge. The Miss Lucases and Miss Bennets discuss Mr. Bingley's social interactions, particularly with Jane Bennet. Mrs. Bennet and her daughters observe Mr. Darcy's aloof behavior, leading to discussions on pride and social status. Elizabeth Bennet expresses her feelings of being slighted by Mr. Darcy's pride.
#
# Summary 9:
#  The text discusses the themes of pride, vanity, and social interactions among characters in "Pride and Prejudice." Mary reflects on human nature's inclination towards pride and self-complacency. The narrative further explores the dynamics between characters like Jane, Elizabeth, Mr. Bingley, and Mr. Darcy. Elizabeth initially dismisses Mr. Darcy's criticism but gradually becomes an object of interest to him. Mr. Darcy recognizes Elizabeth's intelligence and charm despite his initial reservations. The text also delves into the complexities of relationships, societal expectations, and the unpredictability of marriage happiness.
#
# Summary 10:
#  A man at a party becomes intrigued by a woman he initially overlooked and starts paying attention to her conversations. The woman, Elizabeth, notices his actions and discusses them with her friend. When the man, Mr. Darcy, joins their conversation, Elizabeth playfully teases him about hosting a ball. Despite some banter, Elizabeth refuses to dance with Mr. Darcy, causing a stir. Meanwhile, another woman at the party, Mary, lacking talent but eager for attention, takes over the entertainment. Mr. Darcy, disapproving of the superficiality around him, engages in a conversation with Sir William Lucas about dancing and society. Despite a brief attempt to persuade Elizabeth to dance, she declines, earning Mr. Darcy's respect. Miss Bingley then teases Mr. Darcy about his admiration for Elizabeth. The text highlights social dynamics, misunderstandings, and individual personalities at the party.
#
# Summary 11:
#  Mr. Darcy boldly names Miss Elizabeth Bennet as the lady who inspired his reflections, surprising Miss Bingley. The Bennet family's financial situation, with an estate entailed to a distant relation and a mother's modest fortune, is described. The young Bennet sisters, especially Catherine and Lydia, frequently visit Meryton, where a militia regiment's arrival has sparked their interest in officers. Mr. Bennet teases his daughters for their infatuation with officers, and Mrs. Bennet eagerly anticipates a dinner invitation from Miss Bingley. Jane rides to the dinner at Netherfield despite the rain, while Elizabeth helps with the logistics.
#
# Summary 12:
#  Jane Bennet is forced to ride horseback due to the rainy weather after her mother's insistence, while her sisters worry about her. Mrs. Bennet takes credit for the rain, seeing it as lucky. Jane falls ill at Netherfield, and Elizabeth, despite her mother's objections, walks three miles to be with her. The Bingley sisters are surprised by Elizabeth's muddy appearance and hold her in contempt. Mr. Darcy shows kindness towards Elizabeth, while Mr. Hurst focuses on breakfast. Jane's condition worsens, and Elizabeth stays by her side. Elizabeth agrees to stay at Netherfield when offered, and the chapter ends with her being summoned to dinner by Mr. Bingley, who shows concern for Jane's health. Elizabeth finds solace in Mr. Bingley's caring demeanor amidst the indifference of the other guests.
#
# Summary 13:
#  The text describes a scene where Jane's attention is mainly focused on Mr. Bingley, leaving her feeling like an intruder among the others. Miss Bingley criticizes Elizabeth's manners and appearance, while Mr. Darcy defends her. The conversation shifts to the Bennet family's social standing and relationships. Elizabeth declines to play cards, preferring reading. Mr. Bingley offers her books from his library. The conversation then moves to Pemberley's library, with Mr. Darcy and Miss Bingley discussing the importance of books and the estate. The text ends with a conversation about Miss Darcy's accomplishments and the admiration for her.
#
# Summary 14:
#  The text depicts a conversation among characters from "Pride and Prejudice" discussing the concept of accomplishments in women. Mr. Bingley admires the accomplishments of young ladies, while Mr. Darcy and Elizabeth challenge the conventional view. The text also touches upon the illness of Jane Bennet and the interactions between the characters at Netherfield. Mrs. Bennet expresses gratitude for the care provided to Jane. The conversation showcases social dynamics and the characters' personalities.
#
# Summary 15:
#  The text is an excerpt from "Pride and Prejudice" by Jane Austen. It features a conversation among characters discussing the differences between city and country life, character studies, societal observations, and social interactions. Characters like Lizzy, her mother, Bingley, and Darcy engage in a dialogue touching upon various topics such as the value of intricate characters, the social scenes in town versus the countryside, and personal observations about others. The conversation also reveals details about the characters' personalities and relationships, including Lydia's lively demeanor and her eagerness for social events. The scene showcases the dynamics between the characters and their differing perspectives on society and personal interactions.
#
# Summary 16:
#  Mrs. Bennet and her daughters insist on the soldiers giving a ball in Meryton. Elizabeth joins a social gathering with Mr. Darcy and others, observing their interactions. Miss Bingley teases Mr. Darcy about his writing, while Mr. Bingley defends his own quick but incomplete style. The conversation turns to the value of quickness in actions, with Mr. Darcy arguing against hasty decisions. Elizabeth challenges Mr. Bingley's behavior, leading to a discussion on the influence of friendship on decision-making. Mr. Darcy questions the role of friendship in persuasion, highlighting the importance of conviction over compliance. The text showcases the characters' differing views on haste, humility, and the impact of friendship on decision-making.
#
# Summary 17:
#  The text describes a conversation among Bingley, Darcy, Elizabeth, and Miss Bingley regarding the discretion of behavior and intimacy between friends. Bingley jokes about Darcy's height and behavior, causing some tension. Miss Bingley tries to provoke Darcy against Elizabeth due to jealousy. After discussing marriage plans, Miss Bingley gives advice to Darcy about his mother-in-law and Elizabeth. The text also includes playful banter between Elizabeth and Darcy, showing hints of attraction. The ladies have a pleasant conversation before the gentlemen enter, shifting the focus to social dynamics and interactions.
#
# Summary 18:
#  The text describes a social gathering where the gentlemen enter a room and interact with the ladies present. Miss Bingley shows interest in Mr. Darcy, while Mr. Bingley is attentive and joyful towards one of the ladies. The conversation revolves around various topics, and attempts are made to engage Mr. Darcy in social activities. Miss Bingley tries to provoke Mr. Darcy into joining the group but fails. Mr. Darcy is portrayed as serious and focused on reading. The text highlights the dynamics of the social interactions and the different personalities of the characters involved.
#
# Summary 19:
#  The text features a conversation between characters discussing various personality traits, including pride and vanity, in which Mr. Darcy acknowledges his faults but asserts his superiority. Elizabeth and her sister plan to leave Netherfield, facing objections from their mother. Miss Bingley shows jealousy and dislike towards the sisters. Mr. Darcy is relieved by Elizabeth's departure. Upon returning home, the family dynamics shift, and news from the regiment is shared. Mr. Bennet hints at a stranger's arrival, sparking excitement in Mrs. Bennet, who assumes it is Mr. Bingley but is corrected by Mr. Bennet.
#
# Summary 20:
#  Mr. Bennet receives a letter from his cousin, Mr. Collins, informing him of his inheritance of Longbourn estate after Mr. Bennet's death due to entailment. Mrs. Bennet is upset by this news and finds Mr. Collins odious. Mr. Collins expresses his desire to make amends and visit the family, seeking their hospitality. The family expects Mr. Collins, who appears polite and formal, complimenting the daughters' beauty. The daughters are uninterested, but Mrs. Bennet prepares to receive him calmly. Mr. Collins appears eager to please and engages in conversation with the family.
#
# Summary 21:
#  Mr. Collins compliments Mrs. Bennet on her daughters' beauty and predicts they will be well married. Mrs. Bennet expresses concern about the entailment of the estate affecting her daughters' future. During dinner, Mr. Collins praises Lady Catherine de Bourgh, who advises him to marry. He describes Lady Catherine's sickly daughter, Miss de Bourgh, as charming. Mr. Collins flatters Lady Catherine, claiming her daughter is fit for nobility. Mr. Bennet questions if the compliments are rehearsed. Mr. Collins admits to some preparation. At tea, Mr. Collins refuses to read novels, causing surprise.
#
# Summary 22:
#  Mr. Collins is asked to read aloud but refuses novels, opting for "Fordyce's Sermons." Lydia interrupts, mentioning a potential scandal. Collins criticizes young ladies' lack of interest in serious books. He plans to marry a daughter of the Longbourn family for amends. He shifts interest from Jane to Elizabeth, pleasing Mrs. Bennet. Lydia plans to walk to Meryton, with most agreeing to join. Collins is eager to accompany them. In Meryton, they encounter Mr. Wickham, a charming newcomer who had just accepted a commission in the army. Wickham's introduction intrigues the ladies.
#
# Summary 23:
#  A young man in the story is eager to join a regiment to enhance his charm. He is described as having a fine appearance, good figure, and pleasant demeanor. During a social gathering, Mr. Darcy and Mr. Bingley approach the group, with the latter showing interest in Miss Bennet. Mr. Wickham's unexpected arrival causes a stir, particularly between him and Mr. Darcy. Mrs. Phillips, host of the gathering, is impressed by Mr. Collins' manners and invites him for the next evening. Later, Mr. Collins and the young ladies go to Meryton, where Mr. Wickham is also present. The description of Lady Catherine's grandeur captivates the guests. Elizabeth remains unimpressed by Mr. Wickham's entrance. The officers in the group are respectable, but Mr. Wickham stands out in appearance and charm.
#
# Summary 24:
#  Mr. Wickham is the center of attention at a gathering, captivating the women with his charm. He engages in conversation with Elizabeth, discussing Mr. Darcy, revealing a strained relationship due to past events. Wickham shares his disappointment at being denied a valuable living by Mr. Darcy's will. Elizabeth is intrigued by Wickham's story but refrains from probing further due to its sensitive nature. Wickham continues to impress with his social skills and reveals his preference for constant society due to past disappointments. He expresses regret at not pursuing a career in the church as intended.
#
# Summary 25:
#  A man is recounting to Elizabeth the story of how Mr. Darcy unjustly deprived him of a living that was meant for him by his godfather. The man suspects Mr. Darcy's actions were motivated by jealousy and pride due to his close relationship with the man's father. Despite Mr. Darcy's generosity in other aspects, his actions towards the man were deemed cruel and unjust. The man also discusses Miss Darcy's character, revealing her to be proud and less amiable than she once was. Elizabeth expresses surprise at Mr. Darcy's friendship with Mr. Bingley, a charming and amiable man. The conversation shifts to Mr. Collins's lack of success in a whist game, ending the interaction.
#
# Summary 26:
#  The text describes a scene where Mr. Collins downplays his losses at a card game, emphasizing his financial security due to Lady Catherine de Bourgh's support. Mr. Wickham expresses negative opinions about Lady Catherine. Elizabeth shares this with Jane, who is surprised and unwilling to believe Wickham's negative portrayal of Mr. Darcy. They discuss the possibility of deception and the upcoming Netherfield ball, where Mr. Bingley and his sisters invite them. The ladies are excited about the ball and avoid Mrs. Bennet. The conversation shifts to Mr. Darcy and Mr. Bingley's potential involvement in a misunderstanding.
#
# Summary 27:
#  The Bennet family is excited about the upcoming Netherfield ball. Mrs. Bennet is particularly pleased with the invitation from Mr. Bingley. The daughters look forward to dancing and socializing at the ball. Mr. Collins, despite Elizabeth's disappointment, eagerly accepts the invitation to dance. Elizabeth suspects Mr. Darcy's involvement in Mr. Wickham's absence. Despite initial disappointment, Elizabeth eventually enjoys the ball, especially after being freed from dancing with Mr. Collins. The younger Bennet sisters struggle with the anticipation of the ball due to bad weather. Elizabeth's spirits are lifted upon her arrival at the ball, although she is disappointed to learn that Mr. Wickham is not present due to Mr. Darcy's influence. Elizabeth's mood improves as she socializes and dances with other partners, finding solace in the company of her cousin and friend, Charlotte Lucas.
#
# Summary 28:
#  The text describes a scene from "Pride and Prejudice" where Elizabeth dances with various partners, including Mr. Darcy. Despite her initial reluctance, she finds herself unexpectedly accepting his hand for a dance. Their conversation during the dance reveals their similar dispositions towards social interactions and opinions. The interaction is observed by others, leading to further misunderstandings and tensions. Mr. Darcy's demeanor changes when Wickham is mentioned, hinting at underlying conflicts. The text highlights the complex social dynamics and misunderstandings between characters in the story.
#
# Summary 29:
#  The text portrays a conversation between characters discussing various matters, including Mr. Darcy's character and reputation, as well as the background of George Wickham. Miss Bingley attempts to tarnish Wickham's reputation, leading to a confrontation with Elizabeth Bennet defending Wickham. The conversation then shifts to Mr. Bingley's knowledge of Wickham and his reliability. Later, Mr. Collins boasts about discovering a connection to Lady Catherine de Bourgh, intending to pay his respects to her nephew, Mr. Darcy. The text captures a mix of tension, gossip, and social maneuvering among the characters.
#
# Summary 30:
#  Mr. Collins disregards Elizabeth's advice and approaches Mr. Darcy without an introduction, receiving a cold response. Mrs. Bennet eagerly discusses Jane's potential marriage to Mr. Bingley, much to Elizabeth's embarrassment. Despite Elizabeth's attempts to silence her, Mrs. Bennet's loud conversations reach Mr. Darcy, leading to Elizabeth feeling mortified. Mary's singing further adds to Elizabeth's discomfort, as she watches with impatience.
#
# Summary 31:
#  Mary enjoys singing despite her lack of talent, causing discomfort to Elizabeth. Mr. Collins discusses the duties of a clergyman and tries to impress Elizabeth. The evening ends with the Longbourn party leaving, and Mrs. Bennet's hopes of marrying off her daughters. Mr. Collins expresses interest in Elizabeth, who is unimpressed. The following day, a new scene unfolds at Longbourn.
#
# Summary 32:
#  In Chapter XIX of "Pride and Prejudice," Mr. Collins seeks a private audience with Elizabeth to propose marriage. Despite her reluctance, Mrs. Bennet insists Elizabeth stay and hear him out. Mr. Collins states his reasons for marrying, including fulfilling his duty as a clergyman and following Lady Catherine de Bourgh's advice. He also explains his decision to marry one of Mr. Bennet's daughters to lessen the impact of inheriting Longbourn estate. Elizabeth, unable to contain her laughter at Mr. Collins' solemnity, eventually interrupts him.
#
# Summary 33:
#  A clergyman, Mr. Collins, is convinced that getting married will add to his happiness and is advised by Lady Catherine de Bourgh to marry. He intends to marry one of Mr. Bennet's daughters to secure the estate inheritance for the family. Elizabeth, one of Mr. Bennet's daughters, rejects Mr. Collins' proposal despite pressure from her mother to accept. Mrs. Bennet is determined to make Elizabeth marry Mr. Collins but Mr. Bennet remains indifferent to the situation.
#
# Summary 34:
#  A man in the text remains calm and unconcerned when a woman talks to him about Mr. Collins and Lizzy. The woman insists that Lizzy should marry Mr. Collins, but Lizzy refuses. The man, likely Lizzy's father, suggests speaking to Lizzy himself. Mrs. Bennet pressures Lizzy to accept Mr. Collins' proposal, threatening to disown her. Lizzy remains firm in her decision. Mr. Collins, confident in himself, is puzzled by Lizzy's rejection. Charlotte Lucas visits, and the family discusses Lizzy's refusal of Mr. Collins. Mrs. Bennet tries to persuade Lizzy while Lizzy remains resolute. The text also touches on the dynamics between family members and the expectations placed on Lizzy regarding marriage.
#
# Summary 35:
#  The text discusses Mr. Collins's offer, Elizabeth's discomfort with his behavior, and Mr. Collins's pride and resentment. The next day, Mr. Wickham's absence is lamented, and a letter from Caroline Bingley reveals that their party is leaving for town and not returning to Hertfordshire. Elizabeth remains distrustful of the content of the letter and discusses it with Jane. They further learn that Mr. Bingley will not be returning for the winter. The letter also mentions Mr. Darcy's eagerness to see his sister and hints at a potential future connection between their families. Jane is hurt by the contents of the letter and shares her feelings with Elizabeth.
#
# Summary 36:
#  The text discusses a conversation between Jane and Elizabeth from "Pride and Prejudice" regarding Miss Bingley's intentions towards Mr. Bingley and Jane. Elizabeth believes Miss Bingley wants her brother to marry Miss Darcy and tries to convince Jane that Mr. Bingley is not interested in her. Elizabeth advises Jane to refuse Mr. Bingley if his happiness outweighs hers. Miss Bingley's deceitful intentions are revealed, but Jane remains hopeful that Bingley will return. Charlotte Lucas schemes to deflect Mr. Collins' affections towards herself, leading to a favorable outcome for both.
#
# Summary 37:
#  A man earnestly asks a woman to name the day they will marry, even though she feels no inclination towards him. The lady, Miss Lucas, accepts his proposal solely for an establishment and does not care when it happens. Her family, Sir William and Lady Lucas, happily consent to the match due to Mr. Collins' circumstances. Charlotte, though not thrilled with Mr. Collins, sees marriage as a respectable choice for a woman of her background. She plans to inform her friend Elizabeth about the engagement, aware that Elizabeth may disapprove. Mr. Collins' eagerness to share the news is curbed by promises of secrecy. The text ends with Mrs. Bennet expressing happiness at Mr. Collins' promise to return and Mr. Bennet advising caution regarding Lady Catherine's potential disapproval. Charlotte reflects on her decision, while Elizabeth is initially surprised but eventually wishes her friend happiness.
#
# Summary 38:
#  Charlotte justifies her marriage to Mr. Collins to Elizabeth, who struggles to accept the unsuitable match. Sir William Lucas announces Charlotte's engagement to the Bennet family, met with disbelief and disapproval from Mrs. Bennet. Elizabeth confirms the news, trying to ease the situation. Mrs. Bennet remains resentful towards Elizabeth and Sir William. Mr. Bennet finds amusement in the situation and praises Charlotte's foolishness. Jane and the younger sisters react differently to the news. Lady Lucas takes pride in Charlotte's marriage. Elizabeth and Charlotte's relationship strains, leading Elizabeth to lean on Jane for support. Mr. Collins expresses gratitude for the Bennets' role in his engagement and eagerly plans the wedding. Mrs. Bennet is displeased with Mr. Collins' return.
#
# Summary 39:
#  Mrs. Bennet finds the presence of visitors in her home inconvenient and troublesome due to her poor health. She is distressed by Mr. Bingley's continued absence, fearing his sisters' influence in keeping him away. Jane and Elizabeth are uncomfortable with the situation, with Jane concealing her anxiety. Mr. Collins returns but receives a less warm reception. Mrs. Bennet is upset by the idea of Charlotte Lucas taking over the house. Bingley's letter confirms his settled status in London for the winter, causing disappointment for Jane. Elizabeth is angered by Caroline's claims of Bingley's affection for Miss Darcy. Jane expresses her feelings to Elizabeth, hoping Bingley will be forgotten, while Elizabeth remains doubtful.
#
# Summary 40:
#  The text revolves around a conversation between Elizabeth and Jane regarding Jane's feelings towards a man named Mr. Collins and the implications of Charlotte's marriage. Elizabeth expresses strong opinions about Mr. Collins and Charlotte's marriage, believing it to be unwise. Jane defends Charlotte and tries to see the situation positively. The discussion also touches upon Mr. Bingley's behavior and his sisters' influence on him. Elizabeth and Jane differ in their views on these matters. The text ends with Mrs. Bennet's hope for Mr. Bingley's return and Mr. Bennet teasing Elizabeth about her own romantic prospects.
#
# Summary 41:
#  The text discusses various characters' interactions and relationships, particularly focusing on Mr. Wickham, Mr. Collins, and the Bennet family. Mr. Wickham's influence on the Longbourn family is highlighted, along with Mrs. Gardiner's visit and her concerns about Jane and Mr. Bingley's failed match. Mrs. Bennet's grievances and Mrs. Gardiner's attempts to console Elizabeth regarding Jane's situation are also detailed. The text ends with considerations about Jane and Mr. Bingley's potential reunion and the unlikelihood of their paths crossing in the future.
#
# Summary 42:
#  The text describes a conversation between characters discussing Mr. Darcy's influence on Mr. Bingley's separation from Jane, as well as Elizabeth's interactions with Mr. Wickham. Mrs. Gardiner warns Elizabeth about getting involved with Mr. Wickham due to financial impracticality. Elizabeth assures her aunt she will be cautious. The text also touches on social engagements, family dynamics, and romantic interests. Elizabeth promises to be sensible and not rush into any romantic entanglements. The text concludes with Mr. Collins' return to Hertfordshire and the impending marriage of a character.
#
# Summary 43:
#  Mr. Collins returns to Hertfordshire after the Gardiners and Jane leave. Mrs. Bennet is resigned to his upcoming marriage and sarcastically wishes them happiness. The wedding day approaches, and Miss Lucas bids farewell to Elizabeth. Charlotte invites Elizabeth to visit her in Kent. Elizabeth agrees despite foreseeing little pleasure in the visit. Charlotte's letters about her new home and Lady Catherine are positive but lack depth. Elizabeth eagerly waits for news from Jane in London regarding the Bingleys. Jane eventually sees Miss Bingley, who shows indifference, leading Jane to realize the truth about their relationship. Jane writes to Elizabeth expressing her disappointment in Miss Bingley's behavior. Jane decides to end the acquaintance with Miss Bingley. She mentions her uncle and aunt's kindness and advises Elizabeth to visit friends in Hunsford. The letter reveals Jane's disappointment and resolve regarding Miss Bingley's insincerity.
#
# Summary 44:
#  The text describes a letter received by Elizabeth, expressing Miss Bingley's remarks about Mr. Bingley potentially not returning to Netherfield. Elizabeth finds solace in Jane no longer being deceived by Mr. Bingley's sister. She hopes Mr. Bingley marries Mr. Darcy's sister. Elizabeth shares her feelings with Mrs. Gardiner, stating she feels indifferent towards Mr. Bingley and does not regret his loss. Elizabeth plans a trip to Hunsford with Sir William and Maria. She reflects on her feelings towards Mr. Wickham and contemplates his pursuit of another woman. Elizabeth's journey to Hunsford is planned, and she prepares to leave her family, especially her father. Her farewell with Mr. Wickham is amicable. The journey is uneventful, and Elizabeth finds Sir William Lucas and Maria dull companions. Upon arriving at Mr. Gardiner's, Elizabeth is greeted warmly by Jane and spends a pleasant day with her family. Mrs. Gardiner informs Elizabeth about Jane's emotional state and her detachment from Miss Bingley. The text also touches upon Elizabeth's thoughts on Miss King and her indifferent feelings towards Mr. Wickham's actions.
#
# Summary 45:
#  The text describes a conversation between Mrs. Gardiner and Elizabeth regarding Mr. Wickham's behavior and motives, highlighting the themes of marriage and social status. Mrs. Gardiner questions the intentions of Mr. Wickham and Miss King, while Elizabeth defends them. The text then shifts to Elizabeth's visit to the Parsonage at Hunsford, where Mr. Collins shows off his home and garden to her and her companions. Elizabeth observes Charlotte's behavior towards Mr. Collins and reflects on her own feelings of refusal towards him. The chapter ends with Mr. Collins giving a tour of his garden to the guests. Elizabeth appreciates his dedication to his garden, while Charlotte tactfully navigates the visit.
#
# Summary 46:
#  The text describes Mr. Collins leading a group on a tour of a modern building near his house. The group includes Charlotte, who seems pleased to show the house without her husband's help. They discuss Lady Catherine de Bourgh and her upcoming visit. Charlotte praises Lady Catherine as a respectable woman. Later, the group witnesses Mrs. Jenkinson and Miss de Bourgh arriving at the house, prompting excitement. Mr. Collins is thrilled about an invitation to dine at Rosings. He prepares the group for the visit, emphasizing the need for simplicity in attire. The group is eager and nervous about the upcoming dinner at Rosings.
#
# Summary 47:
#  The text describes a visit by characters to Lady Catherine's home at Rosings. Lady Catherine is portrayed as imposing, with a strong presence and authoritative manner. The visitors witness her grandeur and interactions during dinner, where Mr. Collins is overly complimentary. After dinner, Lady Catherine dominates the conversation, giving advice and asking intrusive questions. She remarks on entailing the estate and inquires about the visitors' talents. Elizabeth handles the questions calmly, despite their impertinence, and Lady Catherine expresses surprise at the lack of formal education for Elizabeth and her sisters.
#
# Summary 48:
#  The text describes a conversation between two characters about the absence of a governess in a family with five daughters. The conversation touches on education, society, and family dynamics. Lady Catherine de Bourgh questions Elizabeth Bennet about her upbringing and expresses surprise at the lack of a governess. The text also portrays a social gathering at Rosings, where Lady Catherine dominates the conversation, and Mr. Collins ingratiates himself with her. The chapter ends with Mr. Collins leaving Hunsford after a visit, leaving Elizabeth relieved that his presence will no longer disrupt her routine. The text highlights the social norms, expectations, and interactions in the setting.
#
# Summary 49:
#  A high-ranking lady, though not a county magistrate, takes charge of matters in her parish with great attention. She intervenes in villagers' disputes and ensures harmony. Elizabeth, during her stay at Rosings, finds solace in pleasant conversations with Charlotte and outdoor walks. The impending arrival of Mr. Darcy, highly anticipated by Lady Catherine, adds excitement. When Mr. Darcy and Colonel Fitzwilliam visit, Elizabeth notices Mr. Darcy's reserved behavior. Subsequently, the ladies receive an invitation to Lady Catherine's drawing-room, where Mr. Darcy's interest in Elizabeth becomes apparent. Colonel Fitzwilliam's amiable demeanor and engaging conversation captivate Elizabeth and draw Lady Catherine's attention. Lady Catherine's preference for her nephews over the guests is evident.
#
# Summary 50:
#  Lady Catherine is interested in music and shares her views on the subject with Mr. Darcy and others. She praises her niece's musical abilities and advises others on the importance of practice. Mr. Darcy receives both praise and criticism from Lady Catherine during their conversation. Elizabeth plays the piano for the guests, and Mr. Darcy joins to listen. They engage in playful banter, with Elizabeth teasing Mr. Darcy about his behavior at a ball. Lady Catherine gives feedback on Elizabeth's performance and offers advice on improving her skills. The chapter ends with the guests preparing to leave after the musical interlude.
#
# Summary 51:
#  Lady Catherine gives instructions to Elizabeth on her performance while mixing in advice on execution and taste. Elizabeth receives the instructions politely and stays at the instrument until Lady Catherine's carriage is ready. The next morning, Mr. Darcy unexpectedly visits Elizabeth. They discuss Mr. Bingley's plans and Mrs. Collins's marriage. Mr. Darcy then shifts the conversation to the comfort of the house and Mrs. Collins' settlement near her family. Charlotte suggests Mr. Darcy's visit may indicate his romantic interest in Elizabeth, but they attribute it to lack of activities due to the season. Elizabeth and Charlotte frequently visit the Parsonage, where Colonel Fitzwilliam also visits, showing an interest in Elizabeth. The reason for Mr. Darcy's frequent visits remains unclear.
#
# Summary 52:
#  The text describes Mrs. Collins observing Mr. Darcy's behavior and potential feelings towards her friend, Eliza. Mrs. Collins notices Mr. Darcy's frequent visits to the Parsonage, his lack of animated presence, and his interactions with Eliza. She contemplates the possibility of Mr. Darcy being interested in Eliza, while also considering the potential match between Eliza and Colonel Fitzwilliam. Elizabeth encounters Mr. Darcy in the park multiple times, leading to awkward interactions and discussions about marriage, wealth, and relationships. Colonel Fitzwilliam hints at Mr. Darcy's control over his choices and his guardianship of Miss Darcy. Elizabeth notices Colonel Fitzwilliam's interest in Miss Darcy, leading to a conversation about managing young ladies.
#
# Summary 53:
#  The text describes a conversation between Elizabeth and Colonel Fitzwilliam regarding Mr. Darcy's interference in separating Mr. Bingley and Jane. Elizabeth expresses her disapproval of Darcy's actions and questions his right to judge and control his friend's happiness. She suspects Darcy's pride and desire to keep Bingley for his sister influenced his actions. Elizabeth reflects on Jane's virtues and her family's suitability, ultimately concluding that Darcy's actions have caused significant harm. The text ends with Elizabeth feeling unwell and deciding not to attend a gathering at Rosings. She then reviews Jane's letters, noticing a lack of cheerfulness due to Darcy's interference. Elizabeth finds solace in the thought of reuniting with Jane soon.
#
# Summary 54:
#  The text describes a scene where Elizabeth is surprised by Mr. Darcy's unexpected visit. Mr. Darcy confesses his love for her, despite her deep-rooted dislike towards him. Elizabeth rejects his advances due to his past behavior, especially his role in separating her sister from her love interest, Mr. Wickham. She confronts Mr. Darcy about his mistreatment of Mr. Wickham, highlighting his character flaws and expressing her strong disapproval. Mr. Darcy, initially calm, becomes defensive and tries to justify his actions, but Elizabeth remains firm in her stance against him.
#
# Summary 55:
#  The text portrays a heated exchange between Darcy and Elizabeth, where Darcy expresses his feelings and opinions about their relationship. Darcy admits his faults and pride but also points out Elizabeth's misconceptions. Elizabeth, feeling angry, refutes Darcy's advances and criticizes his arrogance. Darcy, feeling ashamed, abruptly leaves. Elizabeth reflects on the situation, realizing the depth of Darcy's feelings for her but also acknowledging his faults. The next day, Darcy approaches Elizabeth with a letter expressing his intentions without pressuring her. Elizabeth reads the letter with curiosity, and the text ends with Darcy seeking her attention and understanding.
#
# Summary 56:
#  The speaker addresses a person who has accused them of two offenses: separating Mr. Bingley from their sister and ruining Mr. Wickham's prospects. They explain their actions regarding Bingley's preference for the sister and their efforts to prevent an unsuitable marriage. The speaker acknowledges concerns about the sister's family but defends their motives. They express regret for any unintended harm caused and refute the accusation of harming Mr. Wickham by providing details of his past actions. The speaker concludes by defending their decisions and actions, despite potential misunderstandings and consequences.
#
# Summary 57:
#  The text is a passage from "Pride and Prejudice" where a character defends themselves against accusations made by another character. The character recounts the history of their relationship with Mr. Wickham, detailing how their father supported Wickham's education and career aspirations, including intentions for a church position. The character describes Wickham's deceitful nature, detailing instances of manipulation and attempts to elope with the character's sister for her fortune. The character reveals how Wickham's true intentions were revealed, leading to his removal from their lives. The character concludes by asserting the truth of their account and suggests consulting a relative for further confirmation.
#
# Summary 58:
#  Fitzwilliam Darcy writes a letter to Elizabeth, expressing his knowledge of her father's will and suggesting she consult his cousin for further information. Elizabeth, initially not expecting a proposal in the letter, goes through a range of emotions as she reads it. She doubts Mr. Darcy's sincerity, especially regarding his account of Mr. Wickham's actions. Despite trying to discredit the information, she struggles with conflicting feelings of shock and horror. Elizabeth reflects on Wickham's character and past actions, finding it hard to reconcile with Mr. Darcy's accusations. The letter raises doubts in Elizabeth's mind, and she contemplates seeking clarification from Colonel Fitzwilliam. The text shows Elizabeth grappling with the revelations and her changing perceptions of Wickham and Mr. Darcy.
#
# Summary 59:
#  The text describes a situation where a character reflects on past events involving Mr. Darcy and Wickham, realizing her own prejudices and vanity. She acknowledges her misjudgments, especially regarding Mr. Darcy, and feels ashamed of her behavior. The character contemplates the implications of Mr. Darcy's letter, highlighting a shift in perspective upon re-reading it. The narrative also includes interactions with Lady Catherine and Mr. Collins, focusing on social dynamics and the characters' reactions to various situations.
#
# Summary 60:
#  Lady Catherine notices Miss Bennet's low spirits and offers her to stay longer, suggesting she write to her mother to extend her visit. Miss Bennet declines, explaining she must return to town soon as her father needs her. Lady Catherine insists she could stay longer and offers a ride to London in June. Elizabeth declines, sticking to her original plan. Lady Catherine emphasizes the need for a servant to accompany them. Elizabeth reflects on Mr. Darcy's letter, feeling a mix of anger and compassion towards him. She worries about her sister Jane and regrets her family's behavior. Concerns about Jane and Mr. Darcy's character occupy her thoughts. Lady Catherine gives detailed instructions for their journey, showing condescension. Mr. Collins expresses gratitude for Elizabeth's visit before their departure.
#
# Summary 61:
#  The text describes a scene where Elizabeth is being thanked for her visit to Hunsford by Mr. Collins. He expresses pride in introducing her to superior society and their connection with Lady Catherine's family. Elizabeth assures Mr. Collins of her happiness and gratitude. The text then transitions to Elizabeth's journey back home with her sisters, Kitty and Lydia, who are excitedly showing off their purchases. Lydia mentions the upcoming departure of militia troops from Meryton. Elizabeth expresses satisfaction upon hearing this news.
#
# Summary 62:
#  The text describes a conversation between characters discussing plans for the summer, including a potential trip to Brighton. Lydia shares news about a person named Wickham, to the dismay of others. The group then travels back home to Longbourn, where they have a lively dinner conversation. Lydia recounts a humorous incident from the morning, while Mary expresses a preference for books over frivolity. Despite Mary's objections, Lydia insists on visiting Meryton in the afternoon, which Elizabeth opposes.
#
# Summary 63:
#  The text discusses the interactions between characters in "Pride and Prejudice." Lydia's disregard for others' opinions, Elizabeth's concerns about Wickham, and Jane's shock over Wickham's behavior are highlighted. Elizabeth shares her encounter with Mr. Darcy with Jane, who sympathizes with Darcy despite his disappointment. Elizabeth reflects on her changing feelings towards Darcy and Wickham. The conversation ends with Elizabeth deciding not to expose Wickham's character publicly to protect his reputation. The discussion helps Elizabeth feel relieved, having shared her secrets with Jane.
#
# Summary 64:
#  Elizabeth feels relieved after sharing secrets with Jane and contemplates revealing more about Mr. Darcy's letter but refrains. Jane remains unhappy due to her unrequited love for Bingley. Mrs. Bennet dismisses Jane's chances with Bingley and discusses the Collinses' situation. The Bennet family faces dejection as the regiment leaves Meryton, with Kitty and Lydia particularly miserable. Lydia's excitement grows as she receives an invitation to Brighton from Mrs. Forster, causing jealousy in Kitty. Elizabeth worries about Lydia's behavior and its impact on the family's reputation. The chapter ends with Lydia's exuberance over the invitation and Kitty's discontent.
#
# Summary 65:
#  Lydia's behavior worries Elizabeth, who tries to convince her father not to let Lydia go to Brighton due to concerns about her imprudence and the influence of Mrs. Forster. Mr. Bennet dismisses these worries and decides to send Lydia to Brighton with the hope that it will teach her some humility. Elizabeth is disappointed but accepts his decision. Meanwhile, Lydia fantasizes about Brighton, unaware of Elizabeth's concerns. Elizabeth's interactions with Wickham show her growing disillusionment with him, and she becomes uninterested in his flirtations. Wickham's reaction to hearing about Colonel Fitzwilliam raises suspicions.
#
# Summary 66:
#  The text describes a conversation between Elizabeth and Wickham about Mr. Darcy's behavior and character in "Pride and Prejudice." Wickham expresses skepticism about Darcy's improvement in manners and essential qualities, while Elizabeth clarifies that she meant his disposition is better understood with acquaintance. Wickham hints at Darcy's pride and cautiousness, especially in front of his aunt, Lady Catherine. The text also discusses Elizabeth's dissatisfaction with her family dynamics and her anticipation of a trip to the Lakes for solace. The narrative delves into Elizabeth's contemplation of her father's unsuitable marriage and the impact on their family life. It touches upon Elizabeth's concerns about her sisters' behavior and the upcoming trip as a source of happiness amidst domestic challenges.
#
# Summary 67:
#  The text describes the disappointment of Lydia's letters being short and lacking substance, the return of happiness to Longbourn after Lydia's departure, the change in plans for a northern tour due to Mr. Gardiner's business, and the anticipation of visiting Derbyshire. Elizabeth reluctantly agrees to visit Pemberley, fearing to meet Mr. Darcy there. She discreetly investigates the Darcy family's absence before consenting to visit Pemberley with her aunt and uncle. Elizabeth ultimately agrees to visit Pemberley, setting the stage for potential encounters with Mr. Darcy.
#
# Summary 68:
#  The text describes Elizabeth's visit to Pemberley with her family, where she admires the natural beauty of the estate and the tasteful furnishings of the house. She learns about Mr. Darcy's character through conversations with the housekeeper, who praises him highly, contrary to Elizabeth's previous beliefs. The housekeeper also talks about Miss Darcy, Mr. Darcy's sister, highlighting her beauty and accomplishments. Elizabeth is surprised by the positive descriptions of Mr. Darcy and becomes intrigued by the new insights she gains during the visit.
#
# Summary 69:
#  The housekeeper praises Mr. Darcy in a surprising manner, contradicting her previous opinion of him being ill-tempered. Elizabeth is shocked by the positive remarks and wonders if it is the same Mr. Darcy she knows. Mrs. Gardiner also speaks highly of Mr. Darcy's father and anticipates Miss Darcy's happiness. Elizabeth views a painting of Mr. Darcy and feels a newfound appreciation for him. As they leave the house, they unexpectedly meet Mr. Darcy, causing embarrassment and awkwardness. Mr. Darcy's behavior is noticeably different, adding to Elizabeth's discomfort. He eventually leaves abruptly after a strained conversation. Elizabeth is left feeling ashamed and vexed by the encounter.
#
# Summary 70:
# ...
#
# Summary 89:
#  Mr. Darcy unexpectedly visited and spent hours with Elizabeth's uncle to share that he found Lydia and Wickham in London. Darcy's motive was to rectify the situation caused by his own actions, believing it was his duty. He located them through Mrs. Younge and tried to persuade Lydia to return but failed. Wickham revealed he had debts and no clear future plans. Darcy suggested Wickham marry Elizabeth's sister for financial stability, but Wickham hoped for better prospects abroad. Eventually, a settlement was reached with Elizabeth's uncle handling the financial matters. Darcy's role was crucial in resolving the situation, despite his perceived faults.
#
# Summary 90:
#  The text describes a letter from Mr. Gardiner to Elizabeth, discussing Lydia's behavior and Mr. Darcy's involvement in resolving issues related to Lydia and Wickham. Mr. Gardiner expresses his admiration for Mr. Darcy and his efforts. Elizabeth is conflicted by Mr. Darcy's actions and feels a mix of pleasure and pain towards him. She acknowledges the obligations they now have towards him. The text also includes a conversation between Elizabeth and Wickham about Pemberley and Mr. Darcy's presence in town. Elizabeth suspects Mr. Darcy's visit might be related to his potential marriage to Miss de Bourgh. Wickham mentions Mr. Darcy's sister, Georgiana, and Elizabeth expresses her positive opinion of her. Wickham hints at Mr. Darcy's involvement with Miss de Bourgh and praises her improvement over the years.
#
# Summary 91:
#  The text discusses a conversation between two characters, Mr. Wickham and Elizabeth, regarding Mr. Wickham's sister and his interest in sermon-making. Mr. Wickham expresses his contentment with the conversation and the departure of Lydia and himself. Mrs. Bennet is saddened by Lydia's departure but somewhat relieved by news of Mr. Bingley's impending arrival. The text further explores Miss Bennet's reaction to Mr. Bingley's return and her feelings towards his potential visit. Despite Miss Bennet's attempt to downplay her emotions, Elizabeth notices her fluctuating spirits. Elizabeth contemplates the implications of Mr. Bingley's return and the speculations surrounding it, while also observing her sister's reactions.
#
# Summary 92:
#  The text discusses the arrival of Mr. Bingley in Hertfordshire and the mixed reactions of the Bennet family members towards his visit. Mrs. Bennet eagerly anticipates his arrival, while Jane and Elizabeth display discomfort and unease. Elizabeth, despite harboring some positive feelings towards Mr. Bingley, also reflects on Mr. Darcy's presence, causing her internal conflict. Jane remains composed during the meeting, while Elizabeth struggles with her emotions. The text highlights the complex dynamics between the characters as they navigate social expectations and personal sentiments during Mr. Bingley's visit.
#
# Summary 93:
#  The text describes a scene where Mr. Bingley visits the Bennet family, but his behavior is distant and indifferent, especially towards Elizabeth. Mrs. Bennet eagerly talks about her daughter's marriage and Mr. Darcy's involvement. Elizabeth feels embarrassed and wishes to avoid Mr. Darcy. Mr. Bingley's attention is more focused on Jane, Elizabeth's sister, which adds to Elizabeth's discomfort. Eventually, Mr. Bingley and the other gentlemen leave, and Mrs. Bennet plans a dinner for them. Elizabeth tries to brush off her feelings towards Mr. Darcy and focuses on socializing with her family.
#
# Summary 94:
#  Mrs. Bennet is excited about the happy schemes she imagines due to Bingley's good humor during his visit. A large party is held at Longbourn where the arrival of Bingley and his friend is anxiously awaited. Elizabeth observes Bingley's behavior towards her sister Jane and Mr. Darcy during dinner. She hopes for an opportunity to bring Mr. Darcy and her family together. However, her hopes are dashed as Mr. Darcy gets engaged in playing cards with her mother instead. Mrs. Bennet expresses satisfaction with the day's events and anticipates a proposal from Bingley soon. Elizabeth reassures her sister that she no longer has feelings for Mr. Darcy.
#
# Summary 95:
#  The text describes a scene where Mr. Bingley visits the Bennet family, with Mrs. Bennet trying to set him up with one of her daughters. Despite her efforts, Mr. Bingley shows no particular interest in any of the daughters. However, there is a hint of potential romance between Mr. Bingley and Jane Bennet. Mrs. Bennet tries to create opportunities for them to be alone together. Jane and Elizabeth discuss the situation, and Jane expresses her happiness over the possibility of a romantic connection with Mr. Bingley. The chapter ends with a moment of potential intimacy between Jane and Mr. Bingley. Elizabeth witnesses this and realizes the growing affection between them.
#
# Summary 96:
#  The text describes the joy and excitement of Jane's engagement, with her family members expressing their happiness and approval. Bingley is warmly welcomed into the family, and Jane and Elizabeth share conversations about their relationships. Mrs. Bennet is thrilled with the match and envisions a bright future for Jane. The text also touches on Jane's past feelings for Bingley and her gratitude for their current happiness. Elizabeth supports Jane while reflecting on her own prospects. The engagement becomes a topic of discussion within the family, with Mrs. Bennet enthusiastic about Jane's good fortune.
#
# Summary 97:
#  The text describes the arrival of Lady Catherine de Bourgh at Longbourn, surprising the Bennet family. She questions Elizabeth about a rumored engagement between her and Mr. Darcy, which Elizabeth denies. Lady Catherine insists on having the report contradicted. Elizabeth remains composed and does not provide a direct answer to Lady Catherine's inquiries.
#
# Summary 98:
#  Lady Catherine questions Miss Bennet about a potential marriage proposal from her nephew. Miss Bennet refuses to disclose any information. Lady Catherine insists that the marriage between her nephew and Miss Bennet cannot happen as he is already engaged to her daughter. Miss Bennet argues that if there are no other objections, she should be able to marry him. Lady Catherine disapproves due to differences in social status and family background. Miss Bennet stands her ground, refusing to be intimidated or influenced by Lady Catherine's arguments. The conversation escalates with Lady Catherine bringing up Miss Bennet's sister's elopement. Miss Bennet remains firm in her decision, rejecting Lady Catherine's interference and insults.
#
# Summary 99:
#  The text portrays a conversation between Lady Catherine and Elizabeth, where Lady Catherine tries to dissuade Elizabeth from marrying Mr. Darcy due to social status concerns. Elizabeth stands her ground, asserting her independence and happiness as top priorities. Lady Catherine leaves angrily, warning Elizabeth of consequences. Elizabeth contemplates Mr. Darcy's potential response to Lady Catherine's interference. The family is surprised by Lady Catherine's visit. The next day, Elizabeth's father informs her of a surprising letter, leading Elizabeth to anticipate a proposal from Mr. Darcy.
#
# Summary 100:
#  Elizabeth receives a letter from Mr. Collins congratulating her on her sister's upcoming nuptials and warning her against a potential suitor, Mr. Darcy, due to family objections. Her father finds the situation amusing, but Elizabeth is mortified by his remarks about Mr. Darcy's indifference towards her. Later, Mr. Darcy visits Longbourn with Mr. Bingley, and Elizabeth takes a walk with Mr. Darcy, confessing her selfishness and thanking him for his kindness. Elizabeth's feelings towards Mr. Darcy seem to be changing.
#
# Summary 101:
#  Elizabeth expresses her gratitude to Mr. Darcy for his kindness towards her sister, Lydia, even though she feels selfish. Darcy is surprised by her knowledge of his involvement and apologizes for causing her distress. Elizabeth's sentiments have changed since April, and she politely declines Darcy's affectionate advances. They discuss past misunderstandings and Darcy's letter, with Elizabeth assuring him of her changed opinions. Darcy regrets the bitterness in his letter and hopes for a renewed regard. They agree to forget past unpleasantness and focus on the present. Elizabeth appreciates Darcy's philosophy of moving on from painful memories, contrasting with her own struggles.
#
# Summary 102:
#  The text discusses a conversation between two characters, reflecting on past behaviors and changes brought about by their interactions. The characters express gratitude and apologies for past actions, leading to a deeper understanding of each other. The conversation shifts to discussing other characters' engagements and feelings, revealing misunderstandings and clarifications. The characters part ways after a leisurely walk, pondering on future events. The next chapter shows the characters returning home, where they face questions about their whereabouts, with one character concealing the truth. The evening passes quietly, with the characters reflecting on their feelings and potential challenges ahead.
#
# Summary 103:
#  The text describes a conversation between Elizabeth and Jane about Elizabeth's engagement to Mr. Darcy. Jane initially doubts the news but eventually believes Elizabeth. Elizabeth assures Jane of her love for Mr. Darcy and the happiness of their relationship. Mrs. Bennet is surprised by the news and plans a walk for Elizabeth and Mr. Darcy. Elizabeth worries about her mother's reaction to the engagement and the potential impact on her father. Elizabeth's father expresses concern and disbelief about her choice, which upsets her. He requests a private conversation with her.
#
# Summary 104:
#  Elizabeth's father expresses concerns about her acceptance of Mr. Darcy due to her previous dislike of him. Elizabeth defends her attachment to Mr. Darcy, stating her love for him despite her father's doubts. Eventually, her father gives his consent, advising her to esteem her husband for a happy marriage. Elizabeth convinces her father of Mr. Darcy's virtues, leading to his acceptance of the match. The text also describes Mrs. Bennet's ecstatic reaction to the news of Elizabeth's engagement to Mr. Darcy. Elizabeth's mother eagerly plans for the wedding and shows great enthusiasm for their future wealth and status. Elizabeth's relationship with Mr. Darcy progresses positively, with her family members showing approval and admiration for him. Elizabeth playfully questions Mr. Darcy about how he fell in love with her, and he admits that he cannot pinpoint the exact moment but acknowledges her beauty and their evolving relationship.
#
# Summary 105:
#  The text is a conversation between characters from "Pride and Prejudice." Elizabeth and Mr. Darcy discuss their feelings towards each other, with Mr. Darcy admitting his admiration for Elizabeth's lively mind despite her impertinence. Elizabeth questions his behavior, especially towards her sister Jane. Mr. Darcy reveals his true intentions of wanting to make Elizabeth love him. Following their engagement, letters are exchanged among the characters, including Miss Bingley's insincere congratulations and Lady Catherine's anger at the news. The Collinses move to Lucas Lodge to avoid Lady Catherine's wrath. Elizabeth is pleased with the support of her friend Charlotte during this tumultuous time.
#
# Summary 106:
#  Lady Catherine becomes angry upon reading her nephew's letter, prompting Charlotte to want to avoid the situation. Mr. Darcy remains composed despite facing social challenges. Mrs. Phillips's vulgarity tests his patience. Elizabeth tries to shield him from uncomfortable situations. Mrs. Bennet is pleased to see her daughters settled, with Jane and Elizabeth living close by. Kitty improves in society. Mary stays home and reflects on visits. Wickham and Lydia's characters remain unchanged. Lydia hopes for Darcy's assistance in securing a court position. Elizabeth helps them financially but declines further involvement. The couple's lifestyle remains unsettled, relying on others for support. The Bingleys and Miss Bingley adjust to Darcy's marriage. Pemberley becomes a happy home for Georgiana and Elizabeth is well-received there.
#
# Summary 107:
#  After being granted the right to visit Pemberley, the protagonist dropped her resentment and grew even fonder of Georgiana and attentive to Darcy. The sisters' attachment was as Darcy had hoped, with Georgiana having a high opinion of Elizabeth. Despite initial astonishment, Georgiana learned from Elizabeth's instructions about relationships. Lady Catherine was initially indignant about her nephew's marriage but eventually reconciled with the couple, visiting them at Pemberley. The Gardiners were close to Darcy and Elizabeth, who were grateful for bringing them together.
#
# Suammaries of Chunks:
#
# Summary 0:
#  The text discusses various novels by Jane Austen, focusing on the distinctions and preferences among her works, such as "Northanger Abbey," "Persuasion," "Mansfield Park," "Sense and Sensibility," "Emma," and "Pride and Prejudice." It argues in favor of "Pride and Prejudice" as Austen's most perfect work, emphasizing its construction, plot development, character development, and dialogue. The text recognizes Austen's unique humor, character portrayal, and storytelling skills, particularly in "Pride and Prejudice." It delves into the misinterpretation of Austen's supposed cynicism and her talent in dissecting and portraying characters, praising her artistry, perfection, and profound understanding of humanity and art despite limited exposure. The text discusses the characters of Mr. Darcy and Elizabeth Bennet in Austen's novels, praising Darcy as a hero with rational pride and genuine love, while Elizabeth is portrayed as clever, strong-minded, and devoid of ill-nature. The text highlights Elizabeth's unique charm, fearlessness, and freedom from societal expectations, asserting her unmatched appeal among heroines in literature. It also describes scenes and conversations from "Pride and Prejudice," focusing on the Bennet family's interactions, Mrs. Bennet's eagerness for advantageous marriages, and the dynamics between Mr. Bingley, Mr. Darcy, and the Bennet family. The text delves into themes of pride, vanity, and social interactions among characters in "Pride and Prejudice," reflecting on human nature's inclination towards pride and self-complacency. It explores the complexities of relationships, societal expectations, and the unpredictability of marriage happiness, with characters like Mary, Mr. Collins, and the Lucases adding to the narrative. The text concludes with discussions on accomplishments in women, the illness of Jane Bennet, and interactions at Netherfield, highlighting social dynamics, misunderstandings, and individual personalities at play.
#
#
# Final Summary:  The text analyzes various novels by Jane Austen, with a focus on "Pride and Prejudice" as her most exceptional work due to its construction, character development, and dialogue. It praises Austen's humor, character portrayal, and storytelling skills, emphasizing her profound understanding of humanity. The text discusses the characters of Mr. Darcy and Elizabeth Bennet, highlighting Darcy as a rational hero and Elizabeth as a strong-minded and charming heroine. It explores themes of pride, vanity, and social interactions within the novel, reflecting on human nature's tendencies. Additionally, it delves into relationships, societal expectations, and the unpredictability of marriage happiness, with a focus on the Bennet family dynamics and interactions.

# %%
test = """
Once upon a time, in a faraway kingdom nestled between towering mountains and lush forests, there lived a humble blacksmith named William. He resided in a quaint cottage on the outskirts of the village, where the rhythmic clang of his hammer against the anvil echoed through the serene countryside.

William was not just an ordinary blacksmith; he possessed a rare gift bestowed upon him by the gods themselves. His creations were not mere tools or weapons; they were masterpieces, imbued with magic and infused with the essence of the elements.

One chilly autumn morning, as William was busy forging a new sword for the king's royal guard, a stranger arrived at his doorstep. The stranger was tall and cloaked in a dark hooded robe that concealed his features. He spoke in a deep, melodious voice that sent shivers down William's spine.

"I've heard tales of your craftsmanship, blacksmith," the stranger said, his voice carrying an air of mystery. "I seek a weapon of great power, one that can vanquish even the mightiest of foes. Can you help me?"

William hesitated, sensing an aura of darkness surrounding the stranger. But his curiosity got the better of him, and he agreed to forge the weapon the stranger desired.

For days and nights, William toiled tirelessly in his forge, pouring his heart and soul into crafting the most exquisite weapon he had ever made. He forged it from the rarest metals and enchanted it with ancient runes of protection and destruction.

Finally, after weeks of labor, the weapon was complete. It gleamed in the firelight, its blade shimmering with otherworldly energy. William handed it to the stranger, who nodded in silent approval.

But as the stranger took hold of the weapon, a sinister grin spread across his face. "Thank you, blacksmith," he said, his voice dripping with malice. "With this weapon in my hands, I shall unleash chaos upon the land."

Before William could react, the stranger vanished into thin air, leaving behind only a trail of darkness. Horrified by what he had unwittingly unleashed, William knew he had to set things right.

Arming himself with his trusty hammer and the few weapons he had left, William embarked on a perilous journey to stop the stranger and reclaim the weapon he had forged. Along the way, he encountered fierce monsters, treacherous landscapes, and unlikely allies.

But with courage in his heart and determination in his soul, William pressed on, knowing that the fate of the kingdom rested in his hands. And as he finally confronted the stranger in a climactic showdown atop the highest peak of the mountains, he realized that the true power lay not in the weapon he had forged, but in the strength of his spirit and the purity of his intentions.

In the end, it was not blades or spells that decided the outcome of the battle, but the unyielding will of a humble blacksmith who refused to let darkness triumph over light. And as the sun rose once more over the kingdom, casting its golden rays upon the land, William knew that peace had been restored, and that his journey was finally at an end.

But even as he returned to his forge, ready to resume his life of quiet solitude, William could not help but wonder what other adventures awaited him beyond the horizon. For in a world filled with magic and mystery, anything was possible for those brave enough to dream.

And so, the legend of William the blacksmith lived on, whispered in the winds and sung in the songs of bards, a testament to the power of courage, friendship, and the indomitable human spirit.

The end."""

# %%
system_prompt = "Summarize this text "
user_prompt = f"""Get a concise summary of this text:


{test}"""
res = call_openai(system_prompt, user_prompt)

# %%
res.json()
# Out:
# {'id': 'chatcmpl-9MrzVMjSJqfNNU553qdZaGizKrC1f',
#  'object': 'chat.completion',
#  'created': 1715237785,
#  'model': 'gpt-3.5-turbo-0125',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
#     'content': "In a kingdom, blacksmith William crafts a powerful weapon for a mysterious stranger, only to realize the stranger's dark intentions. William embarks on a journey to reclaim the weapon and ultimately triumphs not with the weapon's power but his own courage and spirit. The tale highlights themes of courage, friendship, and the triumph of good over evil, leaving William pondering future adventures."},
#    'logprobs': None,
#    'finish_reason': 'stop'}],
#  'usage': {'prompt_tokens': 766, 'completion_tokens': 76, 'total_tokens': 842},
#  'system_fingerprint': None}

# %%
r = res.json()
r['choices'][0]['message']['content'].strip()
# Out:
# "In a kingdom, blacksmith William crafts a powerful weapon for a mysterious stranger, only to realize the stranger's dark intentions. William embarks on a journey to reclaim the weapon and ultimately triumphs not with the weapon's power but his own courage and spirit. The tale highlights themes of courage, friendship, and the triumph of good over evil, leaving William pondering future adventures."
